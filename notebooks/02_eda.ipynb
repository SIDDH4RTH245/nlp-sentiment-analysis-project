# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/nlp-sentiment-analysis-project/blob/main/notebooks/02_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/imdb_cleaned.csv")

# %%
sns.countplot(x="sentiment", data=df)
plt.title("Sentiment Distribution")
plt.show()

# %%
df["review_length"] = df["review"].apply(len)

sns.histplot(df["review_length"], bins=50)
plt.title("Review Length Distribution")
plt.show()
